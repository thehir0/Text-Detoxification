# %%
import pandas as pd
detox_data = pd.read_csv('../data/raw/filtered.tsv', sep='\t', index_col=0)
detox_data
# Out:
#                                                 reference  \
# 0       If Alkar is flooding her with psychic waste, t...
# 1                               Now you're getting nasty.
# 2                Well, we could spare your life, for one.
# 3               Ah! Monkey, you've got to snap out of it.
# 4                        I've got orders to put her down.
# ...                                                   ...
# 577772  You didn't know that Estelle had stolen some f...
# 577773                    It'il suck the life out of you!
# 577774                   I can't fuckin' take that, bruv.
# 577775  They called me a fucking hero. The truth is I ...
# 577776                               I did not screw him.
#
#                                               translation  similarity  \
# 0       if Alkar floods her with her mental waste, it ...    0.785171
# 1                             you're becoming disgusting.    0.749687
# ...

# %%
detox_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577777 entries, 0 to 577776
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   reference    577777 non-null  object
#  1   translation  577777 non-null  object
#  2   similarity   577777 non-null  float64
#  3   lenght_diff  577777 non-null  float64
#  4   ref_tox      577777 non-null  float64
#  5   trn_tox      577777 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 30.9+ MB

# %% [markdown]
# **We retain only the references where the translated toxicity score is lower than that of the references.**

# %%
detox_data = detox_data[detox_data['ref_tox'] >= detox_data['trn_tox']]
detox_data = detox_data.drop(columns=['similarity', 'lenght_diff', 'ref_tox', 'trn_tox'])
detox_data = detox_data.reset_index(drop=True)
detox_data
# Out:
#                                                 reference  \
# 0       I'm not gonna have a child... ...with the same...
# 1       They're all laughing at us, so we'll kick your...
# 2         Maine was very short on black people back then.
# 3       So now their spirits are cursed, walking back ...
# 4                    Come on, Cal, leave that shit alone.
# ...                                                   ...
# 319137                 I am so crazy nuts about you guys.
# 319138  I thought American men were bad enough, but no...
# 319139                    It'il suck the life out of you!
# 319140                   I can't fuckin' take that, bruv.
# 319141  They called me a fucking hero. The truth is I ...
#
#                                               translation
# 0       I'm not going to breed kids with a genetic dis...
# 1                 they're laughing at us. We'll show you.
# 2                  there wasn't much black in Maine then.
# ...

# %% [markdown]
# **Combine paradetox dataset with our main dataset**

# %%
paradetox_data = pd.read_csv('../data/external/paradetox.tsv', sep='\t')

paradetox_data.head(5)
# Out:
#                                                toxic  \
# 0                           he had steel balls too !
# 1  dude should have been taken to api , he would ...
# 2  im not gonna sell the fucking picture , i just...
# 3  the garbage that is being created by cnn and o...
# 4  the reason they dont exist is because neither ...
#
#                                             neutral1  \
# 0                                  he was brave too!
# 1  It would have been good if he went to api. He ...
# 2  I'm not gonna sell the picture, i just want to...
# 3  the news that is being created by cnn and othe...
# 4  The reason they don't exist is because neither...
#
#                                             neutral2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The news that is being created by cnn and othe...
# ...

# %%
paradetox_data = paradetox_data.drop(columns=paradetox_data.columns.values[2:])
paradetox_data.columns = detox_data.columns.values
paradetox_data
# Out:
#                                                reference  \
# 0                               he had steel balls too !
# 1      dude should have been taken to api , he would ...
# 2      im not gonna sell the fucking picture , i just...
# 3      the garbage that is being created by cnn and o...
# 4      the reason they dont exist is because neither ...
# ...                                                  ...
# 11922     this is the " dumb " shit they 're laughing at
# 11923              no seriously you 're fucking retarded
# 11924              christians love to shit on the pope .
# 11925  but if saying " fuck that group " is much more...
# 11926  shit we probably literally blow that up in a w...
#
#                                              translation
# 0                                      he was brave too!
# 1      It would have been good if he went to api. He ...
# 2      I'm not gonna sell the picture, i just want to...
# ...

# %%
data = pd.concat([detox_data, paradetox_data], ignore_index=True)
data
# Out:
#                                                 reference  \
# 0       I'm not gonna have a child... ...with the same...
# 1       They're all laughing at us, so we'll kick your...
# 2         Maine was very short on black people back then.
# 3       So now their spirits are cursed, walking back ...
# 4                    Come on, Cal, leave that shit alone.
# ...                                                   ...
# 331064     this is the " dumb " shit they 're laughing at
# 331065              no seriously you 're fucking retarded
# 331066              christians love to shit on the pope .
# 331067  but if saying " fuck that group " is much more...
# 331068  shit we probably literally blow that up in a w...
#
#                                               translation
# 0       I'm not going to breed kids with a genetic dis...
# 1                 they're laughing at us. We'll show you.
# 2                  there wasn't much black in Maine then.
# ...

# %% [markdown]
# **Split for the train dataset and test dataset with ratio 0.05**

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(data, test_size=0.05, random_state=32)
train_data
# Out:
#                                                 reference  \
# 269888  precancerous lesions (growths) and cancers in ...
# 238565  If I had two more "man-ginas" like you, I'd be...
# 224612                              How the hell are you?
# 319376             hope they find them and hang em high .
# 140685   I'd better go and see what that old bitch wants.
# ...                                                   ...
# 282558           Dark, a Negro; small and shrewd-looking.
# 322428  a girl like me aint never unloyal so idk what ...
# 75062   If they find out you've seen this, your life w...
# 130949                 Who said shit about arresting you?
# 10967                       Oh, aunt May, you are a riot!
#
#                                               translation
# 269888  precancerous lesions (growth) and cervical can...
# 238565         two more frills and I'll be a millionaire.
# 224612                                hey, how you doing?
# ...

# %%
test_data
# Out:
#                                                 reference  \
# 294194       Hot chicks are starfuckers in Coeur d'Alene.
# 318760                    Oh, Grace, don't be ridiculous.
# 112316                           Two... - Fuck yo sister.
# 34438   Next time you decide to take a bath, Private, ...
# 256660                  I finally caught you, you dirty--
# ...                                                   ...
# 24546        Are you going for the slutty ballerina look?
# 172201             I suppose you wanna fuck, too, do you?
# 59459                  Yeah, we'll totally gang-bang you!
# 323933                     aaron craft can go suck a dick
# 107292          And there was a pathetic, little samurai.
#
#                                               translation
# 294194  hot cats from Coeur D'Alene sands only with fr...
# 318760                             grace, don't be crazy!
# 112316                       two-- - Dead by your sister.
# ...

# %%
train_data.to_csv('../data/interim/train_filtered.csv')
test_data.to_csv('../data/interim/test_filtered.csv')
